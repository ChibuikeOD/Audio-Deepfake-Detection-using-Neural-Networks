# %%
from pydub import AudioSegment

def normalize_audio_input(m4a_path, output_path="Recording.wav"):
    # Load the audio file
    audio = AudioSegment.from_file(m4a_path)
    
    # Convert to mono and set sample rate to 16 kHz
    audio = audio.set_channels(1)
    audio = audio.set_frame_rate(16000)
    
    # Export as wav
    audio.export(output_path, format="wav")
    
    return output_path

normalize_audio_input("Recording.m4a")
# Out:
# 'Recording.wav'

# %%
wav = tf.io.read_file("Recording.wav")
wav.shape
# Out:
# TensorShape([])

# %%
import tensorflow as tf
import tensorflow_hub as hub

yamnet = hub.load('https://tfhub.dev/google/yamnet/1')

wav = tf.io.read_file("Recording.wav")

def extract_audio_embeddings(waveform):
   
       # Ensure 1D tensor (single waveform)
    if len(waveform.shape) > 1:
        waveform = waveform[:, 0]  # Take first channel
        waveform = tf.reshape(waveform, [-1])  # Flatten to 1D

     waveform = tf.convert_to_tensor(waveform, dtype=tf.float32) #yamnet expects inputs to be float32

    scores, embeddings, spectogram = yamnet(waveform)
    clip_embedding = tf.reduce_mean(embeddings, axis=0)  # mean pooling
    return clip_embedding.numpy()  # return as numpy for downstream use

embeddings = extract_audio_embeddings(wav)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 19
#      16     clip_embedding = tf.reduce_mean(embeddings, axis=0)  # mean pooling
#      17     return clip_embedding.numpy()  # return as numpy for downstream use
# ---> 19 embeddings = extract_audio_embeddings(wav)
#
# Cell In[10], line 9, in extract_audio_embeddings(waveform)
#       8 def extract_audio_embeddings(waveform):
# ----> 9     waveform = tf.convert_to_tensor(waveform, dtype=tf.float32) #yamnet expects inputs to be float32
#      10        # Ensure 1D tensor (single waveform)
#      11     if len(waveform.shape) > 1:
#
# File ~/.venvs/tensorflow/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/.venvs/tensorflow/lib/python3.12/site-packages/tensorflow/python/framework/tensor.py:760, in Tensor.__tf_tensor__(self, dtype, name)
#     756 def __tf_tensor__(
#     757     self, dtype: Optional[dtypes.DType] = None, name: Optional[str] = None
#     758     ) -> "Tensor":
#     759   if dtype is not None and not dtype.is_compatible_with(self.dtype):
# --> 760     raise ValueError(
#     761         _add_error_prefix(
#     762             f"Tensor conversion requested dtype {dtype.name} "
#     763             f"for Tensor with dtype {self.dtype.name}: {self!r}",
#     764             name=name))
#     765   return self
#
# ValueError: Tensor conversion requested dtype float32 for Tensor with dtype string: <tf.Tensor: shape=(), dtype=string, numpy=b'RIFFz\xf5\x03\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00\x80>\x00\x00\x00}\x00\x00\x02\x00\x10\x00dataV ...

# %%
wav
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'RIFFz\xf5\x03\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00\x80>\x00\x00\x00}\x00\x00\x02\x00\x10\x00dataV ...
